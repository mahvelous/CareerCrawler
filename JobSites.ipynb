# %%
from selenium import webdriver
import pandas as pd
print("Enter profile")
profile = input()
print(profile)
print("Enter location")
location=input()
print(location)
print("Experience")
experience=input()
print(experience)
# Out:
# Enter profile
# Machine Learning
# Machine Learning
# Enter location
# Bangalore
# Bangalore
# Experience
# 5
# 5

# %%
url = "https://www.monsterindia.com/srp/results?limit=10&query="+profile+"&locations="+location+"&experienceRanges="+experience+"~"+experience+"&experience="+experience
driver = webdriver.Chrome()
driver.get(url)
print("executed")
# Out:
# executed

# %%
job_list=[]
jobs =  driver.find_elements_by_class_name('card-apply-content')
for job in  jobs:
    try:
        cname = job.find_element_by_xpath('div/span/a').text
    except:
        cname = "Not Available"
    try:
        position = job.find_element_by_xpath('div/h3/a').text
    except:
        position = "Not Available"
    try:
        website =job.find_element_by_xpath('div/span/a').get_attribute('href')
    except:
        website = "Not Available"
    try:
        link = job.find_element_by_xpath('div/h3/a').get_attribute('href')
    except:
        link = "Not Available"
    try:
        location = job.find_element_by_xpath('div/div/div[1]/span/small').text
    except:
        location = "Not Available"
    try:
        experience = job.find_element_by_xpath('div/div/div[2]/span/small').text
    except:
        experience ="Not Available"
    try:
        salary = job.find_element_by_xpath('div/div/div[3]/span/small').text
    except:
        salary = "Not Available"
    try:
        description = job.find_element_by_xpath('p[1]').text
    except:
        description = "Not Available"
    job_item={'Company Name':cname,
          'Position':position,
          'Location':location,
          'Experience':experience,
          'Salary':salary,
          'Company Website':website,
          'Apply link':link,
          'Description': description
         }
    job_list.append(job_item)
df = pd.DataFrame(job_list)
df
# Out:
#                                           Apply link  \
# 0  https://www.monsterindia.com/seeker/job-detail...
# 1  https://www.monsterindia.com/seeker/job-detail...
# 2  https://www.monsterindia.com/seeker/job-detail...
# 3  https://www.monsterindia.com/seeker/job-detail...
# 4  https://www.monsterindia.com/seeker/job-detail...
# 5  https://www.monsterindia.com/seeker/job-detail...
# 6  https://www.monsterindia.com/seeker/job-detail...
# 7  https://www.monsterindia.com/seeker/job-detail...
# 8  https://www.monsterindia.com/seeker/job-detail...
# 9  https://www.monsterindia.com/seeker/job-detail...
#
#                                    Company Name  \
# 0                                 Not Available
# 1                              SnapHunt Pte Ltd
# 2                              SnapHunt Pte Ltd
# 3              Larsen & Toubro Infotech Limited
# 4       Ness Technologies India Private Limited
# 5           Flexi Careers India Private Limited
# 6  Grace System Technology Labs (India) Pvt.Ltd
# 7         Invensis Technologies Private Limited
# 8  Convate Consultancy Services Private Limited
# 9                 MNR Solutions Private Limited
#
#                                      Company Website  \
# 0                                      Not Available
# 1  https://www.monsterindia.com/search/snaphunt-p...
# 2  https://www.monsterindia.com/search/snaphunt-p...
# 3  https://company.monsterindia.com/ltitin/index....
# 4  https://www.monsterindia.com/search/ness-techn...
# 5  https://www.monsterindia.com/search/flexi-care...
# 6  https://www.monsterindia.com/search/grace-syst...
# 7  https://www.monsterindia.com/search/invensis-t...
# 8        https://company.monsterindia.com/convatein/
# 9  https://www.monsterindia.com/search/mnr-soluti...
#
#                                          Description  Experience  \
# 0  Developer/Sr-developer/Lead developer/Data Sci...  3-13 Years
# 1  Working with stakeholders to understand needs ...   2-7 Years
# 2  You will play a strategic role in helping us t...   1-6 Years
# 3  Build robust Machine Learning pipeline along w...   4-8 Years
# 4  5 years of experience including statistics, cl...  5-10 Years
# 5                              Junior Data Scientist  4-10 Years
# 6  Immediate Job Opening with our client-Bangalor...  5-10 Years
# 7                                  Software Engineer   3-6 Years
# 8  Greetings Convate!! I am glad to share an oppo...   4-7 Years
# 9  Role: Architect (Technical, Senior- technical,...  5-14 Years
#
#                          Location  \
# 0  Bengaluru / Bangalore, Chennai
# 1    Bengaluru / Bangalore, Delhi
# 2           Bengaluru / Bangalore
# 3           Bengaluru / Bangalore
# 4   Bengaluru / Bangalore, Mumbai
# 5           Bengaluru / Bangalore
# 6           Bengaluru / Bangalore
# 7           Bengaluru / Bangalore
# 8           Bengaluru / Bangalore
# 9   Bengaluru / Bangalore, Mumbai
#
#                                             Position         Salary
# 0  Developer/Sr-developer/Lead developer/Data Sci...  Not Specified
# 1                                      Data Engineer  Not Specified
# 2                                Lead Data Scientist  Not Specified
# 3                                  Pyspark Developer  Not Specified
# 4                                     Data Scientist  Not Specified
# 5                              Junior Data Scientist  Not Specified
# 6                                      Deep Learning  Not Specified
# 7  Immediate Joiners of DL/ML at Heathcare Techno...  Not Specified
# 8  Hiring @ top Audit based for Machine Learning ...  Not Specified
# 9  Architect (Technical, Senior- technical, Princ...  Not Specified

# %%
driver.quit()

# %%
url = "https://www.naukri.com/"+profile+"-jobs-in-"+location
driver = webdriver.Chrome()
driver.get(url)
print("executed")
# Out:
# executed

# %%
jobs =  driver.find_elements_by_class_name('jobTuple')

# %%
job_list=[]
i=0
for job in  jobs:
    try:
        cname = job.find_element_by_xpath('div[1]/div[1]/div/a').text
    except:
        cname = "Not Available"
    try:
        position = job.find_element_by_xpath('div[1]/div[1]/a').get_attribute('title')
    except:
        position = "Not Available"
    try:
        website = job.find_element_by_xpath('div[1]/div[1]/div/a').get_attribute('href')
    except:
        website = "Not Available"
    try:
        link = job.find_element_by_xpath('div[1]/div[1]/a').get_attribute('href')
    except:
        link = "Not Available"
    try:
        location = job.find_element_by_xpath('div[1]/div[1]/ul/li[3]/span').text
    except:
        location = "Not Available"
    try:
        experience = job.find_element_by_xpath('div[1]/div[1]/ul/li[1]/span').text
    except:
        experience ="Not Available"
    try:
        salary = job.find_element_by_xpath('div[1]/div[1]/ul/li[2]/span').text
    except:
        salary = "Not Available"
    job_item={'Company Name':cname,
          'Position':position,
          'Location':location,
          'Experience':experience,
          'Company Website':website,
          'Apply link':link,
          'Salary':salary
         }
    job_list.append(job_item)
    i+=1
    if i==10:
        break
df = pd.DataFrame(job_list)
df
# Out:
#                                           Apply link  \
# 0  https://www.naukri.com/job-listings-research-s...
# 1  https://www.naukri.com/job-listings-machine-le...
# 2  https://www.naukri.com/job-listings-artificial...
# 3  https://www.naukri.com/job-listings-sr-manager...
# 4  https://www.naukri.com/job-listings-assistant-...
# 5  https://www.naukri.com/job-listings-ai-machine...
# 6  https://www.naukri.com/job-listings-fresher-in...
# 7  https://www.naukri.com/job-listings-data-scien...
# 8  https://www.naukri.com/job-listings-software-d...
# 9  https://www.naukri.com/job-listings-senior-man...
#
#                                   Company Name  \
# 0                                       Resson
# 1                           eInfochips Limited
# 2                   Hewlett Packard Enterprise
# 3                            Axim Technologies
# 4                    Huquo Consulting Pvt. Ltd
# 5                       Zycus Infotech Pvt Ltd
# 6                Creative Hands HR Consultancy
# 7                             The Hiring Story
# 8                                    Careerera
# 9  Amazon Development Centre (India) Pvt. Ltd.
#
#                                      Company Website Experience  \
# 0  https://www.naukri.com/resson-jobs-careers-302...    2-6 Yrs
# 1  https://www.naukri.com/einfochips-jobs-careers...   8-12 Yrs
# 2  https://www.naukri.com/hewlett-packard-enterpr...    4-8 Yrs
# 3  https://www.naukri.com/premium-jobs-jobs-caree...  12-18 Yrs
# 4  https://www.naukri.com/premium-jobs-careers-85...    3-8 Yrs
# 5  https://www.naukri.com/zycus-infotech-jobs-car...    1-6 Yrs
# 6  https://www.naukri.com/creative-hands-hr-consu...    0-0 Yrs
# 7  https://www.naukri.com/premium-jobs-careers-85...    4-8 Yrs
# 8  https://www.naukri.com/careerera-jobs-careers-...    3-5 Yrs
# 9  https://www.naukri.com/amazon-jobs-careers-194374  12-18 Yrs
#
#                                             Location  \
# 0                                        Navi Mumbai
# 1                   Bengaluru(6th block Koramangala)
# 2                                          Bengaluru
# 3                               Bengaluru, Hyderabad
# 4                                          Bengaluru
# 5                                          Bengaluru
# 6  Chennai, Mumbai, Ahmedabad, Bengaluru, Hyderab...
# 7                                             Mumbai
# 8                                          Bengaluru
# 9                                          Bengaluru
#
#                                             Position                   Salary
# 0      Research Software Developer (computer Vision)            Not disclosed
# 1  Machine learning Engineer [ML,Azure ML,Azure M...            Not disclosed
# 2  Artificial Intelligence / Machine Learning Eng...            Not disclosed
# 3                     Sr. Manager - Machine Learning            Not disclosed
# 4  Assistant Manager/ Manager/ Data Scientist - P...            Not disclosed
# 5  AI/ Machine Learning Engineer (premium college...            Not disclosed
# 6  Fresher / Intern Jobs in Machine Learning Proj...  3,00,000 - 4,00,000 PA.
# 7  Data Scientist - Machine Learning/artificial I...            Not disclosed
# 8  Software Developer - NLP | Machine Learning/ D...            Not disclosed
# 9                    Senior Manager Machine Learning            Not disclosed

# %% [raw]
# driver.quit()

# %%
url = "https://in.linkedin.com/jobs/search?keywords="+profile+"&location="+location
driver = webdriver.Chrome()
driver.get(url)
print("executed")
# Out:
# executed

# %%
job_list=[]
jobs =  driver.find_elements_by_class_name('result-card__contents')

# %%
for job in  jobs:
    try:
        cname = job.find_element_by_xpath('h4/a').text
    except:
        cname = "Not Available"
    try:
        position = job.find_element_by_xpath('h3').text
    except:
        position = "Not Available"
    try:
        website =job.find_element_by_xpath('h4/a').get_attribute('href')
    except:
        website = "Not Available"
    try:
        link = job.find_element_by_xpath('h4/a').get_attribute('href')
    except:
        link = "Not Available"
    try:
        location = job.find_element_by_xpath('div/span[1]').text
    except:
        location = "Not Available"
    job_item={'Company Name':cname,
          'Position':position,
          'Location':location,
          'Company Website':website,
          'Apply link':link,
         }
    job_list.append(job_item)
df = pd.DataFrame(job_list)
df
# Out:
#                                            Apply link  \
# 0   https://www.linkedin.com/company/google?trk=pu...
# 1   https://www.linkedin.com/company/apple?trk=pub...
# 2   https://in.linkedin.com/company/siemens-techno...
# 3   https://www.linkedin.com/company/zycus?trk=pub...
# 4   https://in.linkedin.com/company/lincode-india?...
# 5   https://www.linkedin.com/company/vmware?trk=pu...
# 6                                       Not Available
# 7   https://www.linkedin.com/company/autodesk?trk=...
# 8   https://www.linkedin.com/company/qualcomm?trk=...
# 9   https://in.linkedin.com/company/huawei-india-r...
# 10  https://www.linkedin.com/company/amazon?trk=pu...
# 11  https://www.linkedin.com/company/twilio-inc-?t...
# 12  https://www.linkedin.com/company/danaher-digit...
# 13  https://uk.linkedin.com/company/michael-page?t...
# 14  https://www.linkedin.com/company/utopia-inc?tr...
# 15  https://in.linkedin.com/company/hyperverge-inc...
# 16  https://in.linkedin.com/company/righthireporta...
# 17  https://in.linkedin.com/company/qpiai?trk=publ...
# 18  https://jp.linkedin.com/company/sony?trk=publi...
# 19  https://in.linkedin.com/company/xfinito-biodes...
# 20  https://in.linkedin.com/company/roposo-com?trk...
# 21  https://in.linkedin.com/company/machstatz-busi...
# 22  https://www.linkedin.com/company/paypal?trk=pu...
# 23  https://in.linkedin.com/company/l&t-technology...
#
#                        Company Name  \
# 0                            Google
# 1                             Apple
# 2          Siemens Technology India
# 3                             Zycus
# 4                     Lincode India
# 5                            VMware
# 6                     Not Available
# 7                          Autodesk
# 8                          Qualcomm
# 9         Huawei Technologies India
# 10                           Amazon
# 11                      Twilio Inc.
# 12              Danaher Digital LLC
# 13                     Michael Page
# 14              Utopia Global, Inc.
# 15                  HyperVerge Inc.
# 16                        RightHire
# 17                            QpiAI
# 18                             Sony
# 19               Xfinito Biodesigns
# 20                           Roposo
# 21                        Machstatz
# 22                           PayPal
# 23  L&T Technology Services Limited
#
#                                       Company Website  \
# 0   https://www.linkedin.com/company/google?trk=pu...
# 1   https://www.linkedin.com/company/apple?trk=pub...
# 2   https://in.linkedin.com/company/siemens-techno...
# 3   https://www.linkedin.com/company/zycus?trk=pub...
# 4   https://in.linkedin.com/company/lincode-india?...
# 5   https://www.linkedin.com/company/vmware?trk=pu...
# 6                                       Not Available
# 7   https://www.linkedin.com/company/autodesk?trk=...
# 8   https://www.linkedin.com/company/qualcomm?trk=...
# 9   https://in.linkedin.com/company/huawei-india-r...
# 10  https://www.linkedin.com/company/amazon?trk=pu...
# 11  https://www.linkedin.com/company/twilio-inc-?t...
# 12  https://www.linkedin.com/company/danaher-digit...
# 13  https://uk.linkedin.com/company/michael-page?t...
# 14  https://www.linkedin.com/company/utopia-inc?tr...
# 15  https://in.linkedin.com/company/hyperverge-inc...
# 16  https://in.linkedin.com/company/righthireporta...
# 17  https://in.linkedin.com/company/qpiai?trk=publ...
# 18  https://jp.linkedin.com/company/sony?trk=publi...
# 19  https://in.linkedin.com/company/xfinito-biodes...
# 20  https://in.linkedin.com/company/roposo-com?trk...
# 21  https://in.linkedin.com/company/machstatz-busi...
# 22  https://www.linkedin.com/company/paypal?trk=pu...
# 23  https://in.linkedin.com/company/l&t-technology...
#
#                        Location  \
# 0   Bengaluru, Karnataka, India
# 1   Bengaluru, Karnataka, India
# 2   Bengaluru, Karnataka, India
# 3   Bengaluru, Karnataka, India
# 4      Anekal, Karnataka, India
# 5   Bengaluru, Karnataka, India
# 6   Bengaluru, Karnataka, India
# 7   Bengaluru, Karnataka, India
# 8   Bengaluru, Karnataka, India
# 9      Anekal, Karnataka, India
# 10  Bengaluru, Karnataka, India
# 11  Bengaluru, Karnataka, India
# 12  Bengaluru, Karnataka, India
# 13  Bengaluru, Karnataka, India
# 14       Greater Bengaluru Area
# 15  Bengaluru, Karnataka, India
# 16  Bengaluru, Karnataka, India
# 17  Bengaluru, Karnataka, India
# 18  Bengaluru, Karnataka, India
# 19  Bengaluru, Karnataka, India
# 20  Bengaluru, Karnataka, India
# 21  Bengaluru, Karnataka, India
# 22  Bengaluru, Karnataka, India
# 23  Bengaluru, Karnataka, India
#
#                                              Position
# 0                 Software Engineer, Machine Learning
# 1                               Machine Learning Lead
# 2   Research Engineer - Data Analytics & Artificia...
# 3              AI/Machine Learning-NLP, Deep Learning
# 4                    Artificial Intelligence Engineer
# 5               MTS3, R&D: Machine Learning Platforms
# 6                           Machine Learning Engineer
# 7            Machine Learning Engineer/Data Scientist
# 8                  Machine Learning Compiler Engineer
# 9                         Data Science or ML Engineer
# 10                         Applied Scientist - Intern
# 11               Software Engineer - Machine Learning
# 12                          Machine Learning Engineer
# 13            Director- Big data and Machine Learning
# 14                   Senior Machine Learning Engineer
# 15                               Deep Learning Intern
# 16                              Junior Data Scientist
# 17                       Scientist AI/Video Analytics
# 18         Data Scientist / Machine Learning Engineer
# 19                 Artificial Intelligence Specialist
# 20                            Machine Learning Expert
# 21                          Machine Learning Engineer
# 22                                   Data Scientist 2
# 23                      Deep Learning Complier Expert

# %%
driver.quit()

# %%
url = "https://www.indeed.co.in/jobs?q="+profile+"&l="+location
driver = webdriver.Chrome()
driver.get(url)
print("executed")
# Out:
# executed

# %%
jobs =  driver.find_elements_by_class_name('jobsearch-SerpJobCard')

# %%
job_list=[]
i=0
for job in  jobs:
    try:
        cname = job.find_element_by_xpath('div[1]/div[1]/span').text
    except:
        cname = "Not Available"
    try:
        position = job.find_element_by_xpath('h2/a').get_attribute('title')
    except:
        position = "Not Available"
    try:
        website = job.find_element_by_xpath('h2/a').get_attribute('href')
    except:
        website = "Not Available"
    try:
        link = job.find_element_by_xpath('h2/a').get_attribute('href')
    except:
        link = "Not Available"
    try:
        location = job.find_element_by_xpath('div[1]/div[3]').text
    except:
        location = "Not Available"
    try:
        experience = job.find_element_by_xpath('').text
    except:
        experience ="Not Available"
    try:
        salary = job.find_element_by_xpath('div[2]/span/span').text
    except:
        salary ="Not Available"
    job_item={'Company Name':cname,
          'Position':position,
          'Location':location,
          'Salary':salary,
          'Company Website':website,
          'Apply link':link
         }
    job_list.append(job_item)
    i+=1
    if i==10:
        break
df = pd.DataFrame(job_list)
df
# Out:
#                                           Apply link  \
# 0  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...
# 1  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...
# 2  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...
# 3  https://www.indeed.co.in/company/Prism/jobs/Ma...
# 4  https://www.indeed.co.in/rc/clk?jk=5fe2a3ef7ca...
# 5  https://www.indeed.co.in/rc/clk?jk=38b78b7a3d6...
# 6  https://www.indeed.co.in/rc/clk?jk=767f35fb967...
# 7  https://www.indeed.co.in/rc/clk?jk=9f73a49bcf7...
# 8  https://www.indeed.co.in/company/Rubixe/jobs/J...
# 9  https://www.indeed.co.in/company/Ikara-Vision-...
#
#                  Company Name  \
# 0               Not Available
# 1                       Mylan
# 2           Ultramatics, Inc.
# 3                       Prism
# 4              Archeron Group
# 5              Archeron Group
# 6  Hewlett Packard Enterprise
# 7               Wipro Limited
# 8                      Rubixe
# 9        Ikara Vision Systems
#
#                                      Company Website              Location  \
# 0  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...         Not Available
# 1  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...  Bengaluru, Karnataka
# 2  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...  Bengaluru, Karnataka
# 3  https://www.indeed.co.in/company/Prism/jobs/Ma...         Not Available
# 4  https://www.indeed.co.in/rc/clk?jk=5fe2a3ef7ca...         Not Available
# 5  https://www.indeed.co.in/rc/clk?jk=38b78b7a3d6...         Not Available
# 6  https://www.indeed.co.in/rc/clk?jk=767f35fb967...         Not Available
# 7  https://www.indeed.co.in/rc/clk?jk=9f73a49bcf7...         Not Available
# 8  https://www.indeed.co.in/company/Rubixe/jobs/J...         Not Available
# 9  https://www.indeed.co.in/company/Ikara-Vision-...         Not Available
#
#                                             Position  \
# 0    Software Engineer - Machine Learning with Cloud
# 1                                Data Lake Developer
# 2            Senior Application Engineer - Bangalore
# 3                          Machine Learning Engineer
# 4                        Machine Learning Researcher
# 5                   Machine Learning & AI Researcher
# 6  Artificial Intelligence / Machine Learning Eng...
# 7                     AWS Machine Learning-Developer
# 8                              Junior Data Scientist
# 9            Deep Learning/ Computer Vision Engineer
#
#                            Salary
# 0                   Not Available
# 1  ₹15,00,000 - ₹23,00,000 a year
# 2                   Not Available
# 3   ₹1,00,000 - ₹1,50,000 a month
# 4                   Not Available
# 5                   Not Available
# 6                   Not Available
# 7                   Not Available
# 8       ₹15,000 - ₹30,000 a month
# 9  ₹12,00,000 - ₹18,00,000 a year
